# %%
# !pip install klib
# Out:
# Requirement already satisfied: klib in c:\users\lakha\anaconda3\lib\site-packages (1.0.7)
# Requirement already satisfied: pandas<2.0.0,>=1.2.0 in c:\users\lakha\anaconda3\lib\site-packages (from klib) (1.4.4)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.3 in c:\users\lakha\anaconda3\lib\site-packages (from klib) (3.5.2)
# Requirement already satisfied: numpy<2.0.0,>=1.16.3 in c:\users\lakha\anaconda3\lib\site-packages (from klib) (1.21.5)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in c:\users\lakha\anaconda3\lib\site-packages (from klib) (3.1.2)
# Requirement already satisfied: seaborn<0.13.0,>=0.11.2 in c:\users\lakha\anaconda3\lib\site-packages (from klib) (0.11.2)
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in c:\users\lakha\anaconda3\lib\site-packages (from klib) (1.9.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lakha\anaconda3\lib\site-packages (from Jinja2<4.0.0,>=3.0.3->klib) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lakha\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lakha\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lakha\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lakha\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lakha\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lakha\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lakha\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lakha\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.2.0->klib) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\lakha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib) (1.16.0)

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import klib

# %%
klib.cat_plot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15536\2222831409.py in <module>
# ----> 1 klib.cat_plot(df)
#
# ~\anaconda3\lib\site-packages\klib\describe.py in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     115         data[col] = data[col].rolling(2, min_periods=1).mean()
#     116
# --> 117         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     118         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     119         sum_top = sum(value_counts_top)
#
# ~\anaconda3\lib\site-packages\klib\describe.py in <listcomp>(.0)
#     115         data[col] = data[col].rolling(2, min_periods=1).mean()
#     116
# --> 117         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     118         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     119         sum_top = sum(value_counts_top)
#
# TypeError: 'bool' object is not subscriptable

# %%
#klib.corr_mat(df)

# %%
#klib.corr_plot(df)

# %%
klib.dist_plot(df)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (784, 15) - Remaining NAs: 692
#
#
# Dropped rows: 107
#      of which 107 duplicates. (Rows (first 150 shown): [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)
#      survived  pclass     sex   age  sibsp  parch       fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.250000        S  Third
# 1           1       1  female  38.0      1      0  71.283302        C  First
# 2           1       3  female  26.0      0      0   7.925000        S  Third
# 3           1       1  female  35.0      1      0  53.099998        S  First
# 4           0       3    male  35.0      0      0   8.050000        S  Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...    ...
# 779         0       3  female  39.0      0      5  29.125000        Q  Third
# 780         1       1  female  19.0      0      0  30.000000        S  First
# 781         0       3  female   NaN      1      2  23.450001        S  Third
# 782         1       1    male  26.0      0      0  30.000000        C  First
# 783         0       3    male  32.0      0      0   7.750000        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 779  woman       False  NaN   Queenstown    no  False
# 780  woman       False    B  Southampton   yes   True
# 781  woman       False  NaN  Southampton    no  False
# 782    man        True    C    Cherbourg   yes   True
# 783    man        True  NaN   Queenstown    no   True
#
# [784 rows x 15 columns]

# %%
df_clean = klib.clean_column_names(df)
df_clean
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
